# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import numpy as np

# generar conjunto de datos
m = 100 
X = 6 * np.random.rand(m, 1)
y = 2 + X + np.random.rand(m, 1) * 2

lin_reg = LinearRegression()
lin_reg.fit(X, y)

X_plot = np.linspace(0, 6, m).reshape(m, 1)
y_plot = lin_reg.predict(X_plot)

plt.scatter(X, y, s=20, c='#18EF62', alpha=0.9)
plt.plot(X_plot, y_plot, color='#3AAAFF', linewidth=4)

# evaluar modelo con ECM
y_pred = lin_reg.predict(X)
lin_mse = mean_squared_error(y, y_pred)
print(lin_mse)

# evaluar modelo con Cross-Validation
cross_scores = cross_val_score(lin_reg, X, y, scoring='neg_mean_squared_error', cv=10)
print(-cross_scores)

# calculamos el promedio de cross_scores
cross_scores_mean = np.mean(-cross_scores)
print(cross_scores_mean)
# Out:
# 0.34608571804249083
# [0.34771415 0.35310847 0.22385622 0.23068933 0.31294677 0.31647544
#  0.35798302 0.45087489 0.35840666 0.57877839]
# 0.3530833351188542
